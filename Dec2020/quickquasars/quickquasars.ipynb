# %%
import os
import sys
import glob as glob
from scipy.signal import medfilt
import matplotlib.pyplot as plt
import seaborn as sb
import healpy
import numpy as np
import desispec.io
import fitsio
sb.set_style('white')

# %% [markdown]
# # In this notebook we will simulate Lyman alpha quasar spectra using the DESI code quickqusars

# %% [markdown]
# ## First let us define some useful functions for visualization

# %%
#A simple filter was added to retain some of the noise and check this is reproduced,
#but still be able to spot differences due to features by eye. 
#Plotspec routine was taken https://github.com/desihub/tutorials/blob/master/Intro_to_DESI_spectra.ipynb. 
#It allows to add the true spectra although we will not use this option here 
#These plots will show the three arms of the spectrograph in colors blue ['b'], red ['r'] and yellow ['z'].


def plotspec(spectra, i, truewave=None, trueflux=None, color=['b','r','y'],nfilter=1,label=None):
    plt.plot(spectra.wave['b'], medfilt(spectra.flux['b'][i], nfilter), color=color[0], alpha=0.5,label=label)
    plt.plot(spectra.wave['r'], medfilt(spectra.flux['r'][i], nfilter), color=color[1], alpha=0.5)
    plt.plot(spectra.wave['z'], medfilt(spectra.flux['z'][i], nfilter), color=color[2], alpha=0.5)
    if truewave is not None and trueflux is not None:
        plt.plot(truewave, trueflux[i], 'k-')

    plt.axhline(0, color='k', alpha=0.2)
        
    ymax = np.max(spectra.flux['b'][i])
    ymin=0
        
    plt.ylim(ymin, ymax+3)
    plt.ylabel('Flux')
    plt.xlabel('wavelength [A]')
    plt.legend(loc='best')
    return
    
#This will compare two spectra by dividing the first over the second
def plotspec_ratio(spectra1,spectra2,i,label=None):
    ratio_b=spectra1.flux['b'][i]/spectra2.flux['b'][i]
    ratio_r=spectra1.flux['r'][i]/spectra2.flux['r'][i]
    ratio_z=spectra1.flux['z'][i]/spectra2.flux['z'][i]
    plt.plot(spectra1.wave['b'],ratio_b, color='b', alpha=0.5,label=label)
    plt.plot(spectra1.wave['r'], ratio_r, color='r', alpha=0.5)
    plt.plot(spectra1.wave['z'], ratio_z, color='y', alpha=0.5)
    plt.xlabel('wavelength [A]')
    plt.legend(loc='best')
    
#This will compare two spectra by substracting the second from the first one
def plotspec_diff(spectra1,spectra2,i,label=None):
    ratio_b=spectra1.flux['b'][i]-spectra2.flux['b'][i]
    ratio_r=spectra1.flux['r'][i]-spectra2.flux['r'][i]
    ratio_z=spectra1.flux['z'][i]-spectra2.flux['z'][i]
    plt.plot(spectra1.wave['b'],ratio_b, color='b', alpha=0.5)
    plt.plot(spectra1.wave['r'], ratio_r, color='r', alpha=0.5)
    plt.plot(spectra1.wave['z'], ratio_z, color='y', alpha=0.5)
    plt.xlabel('wavelength [A]')
    if label!=None:
        plt.legend(loc='best')

#This is only to compute the observed wavelenght of given line that corresponds to the quasar redshift. e.g 

def draw_obsline(lbda,z):
    return (1.+z)*lbda

# %% [markdown]
# # Let's see what are the parameters needed to run a quickquasars simulation

# %%
# !quickquasars --help
# Out:
# usage: quickquasars [-h] -i [INFILE ...] [-o OUTFILE] [--outdir OUTDIR]
#                     [--program PROGRAM] [--seeing SEEING] [--airmass AIRMASS]
#                     [--exptime EXPTIME] [--moonfrac MOONFRAC]
#                     [--moonalt MOONALT] [--moonsep MOONSEP] [--seed SEED]
#                     [--skyerr SKYERR] [--downsampling DOWNSAMPLING]
#                     [--zmin ZMIN] [--zmax ZMAX] [--wmin WMIN] [--wmax WMAX]
#                     [--dwave DWAVE] [--dwave_desi DWAVE_DESI] [--zbest]
#                     [--sigma_kms_fog SIGMA_KMS_FOG]
#                     [--gamma_kms_zfit [GAMMA_KMS_ZFIT]]
#                     [--shift_kms_los SHIFT_KMS_LOS] [--target-selection]
#                     [--mags] [--bbflux] [--add-LYB] [--metals [METALS ...]]
#                     [--metals-from-file [METALS_FROM_FILE]] [--dla DLA]
#                     [--balprob BALPROB] [--no-simqso] [--save-continuum]
#                     [--save-continuum-dwave SAVE_CONTINUUM_DWAVE]
#                     [--desi-footprint] [--eboss] [--extinction]
#                     [--no-transmission] [--nproc NPROC] [--overwrite]
#                     [--nmax NMAX] [--save-resolution]
#
# Fast simulation of QSO Lya spectra into the final DESI format (Spectra class)
# that can be directly used as an input to the redshift fitter (redrock) or
# correlation function code (picca). The input file is a Lya transmission skewer
# fits file which format is described in
# https://desi.lbl.gov/trac/wiki/LymanAlphaWG/LyaSpecSim.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -i [INFILE ...], --infile [INFILE ...]
#                         Input skewer healpix fits file(s) (default: None)
#   -o OUTFILE, --outfile OUTFILE
#                         Output spectra (only used if single input file)
#                         (default: None)
#   --outdir OUTDIR       Output directory (default: .)
#   --program PROGRAM     Program (DARK, GRAY or BRIGHT) (default: DARK)
#   --seeing SEEING       Seeing FWHM [arcsec] (default: None)
#   --airmass AIRMASS     Airmass (default: None)
#   --exptime EXPTIME     Exposure time [sec] (default: None)
#   --moonfrac MOONFRAC   Moon illumination fraction; 1=full (default: None)
#   --moonalt MOONALT     Moon altitude [degrees] (default: None)
#   --moonsep MOONSEP     Moon separation to tile [degrees] (default: None)
#   --seed SEED           Global random seed (will be used to generate a seed
#                         per each file (default: None)
#   --skyerr SKYERR       Fractional sky subtraction error (default: 0.0)
#   --downsampling DOWNSAMPLING
#                         fractional random down-sampling (value between 0 and
#                         1) (default: None)
#   --zmin ZMIN           Min redshift (default: 0)
#   --zmax ZMAX           Max redshift (default: 10)
#   --wmin WMIN           Min wavelength (obs. frame) (default: 3500)
#   --wmax WMAX           Max wavelength (obs. frame) (default: 10000)
#   --dwave DWAVE         Internal wavelength step (don't change this) (default:
#                         0.2)
#   --dwave_desi DWAVE_DESI
#                         Output wavelength step for DESI mocks) (default: 0.8)
#   --zbest               add a zbest file per spectrum either with the truth
#                         redshift or adding some error (optionally use it with
#                         --sigma_kms_fog and/or --gamma_kms_zfit) (default:
#                         False)
#   --sigma_kms_fog SIGMA_KMS_FOG
#                         Adds a gaussian error to the quasar redshift that
#                         simulate the fingers of god effect (default: 150)
#   --gamma_kms_zfit [GAMMA_KMS_ZFIT]
#                         Adds a Lorentzian distributed shift to the quasar
#                         redshift, to simulate the redshift fitting step. E.g.
#                         --gamma_kms_zfit 400 will use a gamma parameter of 400
#                         km/s . If a number is not specified, a value of 400 is
#                         used. (default: None)
#   --shift_kms_los SHIFT_KMS_LOS
#                         Adds a shift to the quasar redshift written in the
#                         zbest file (in km/s) (default: 0)
#   --target-selection    apply QSO target selection cuts to the simulated
#                         quasars (default: False)
#   --mags                DEPRECATED; use --bbflux (default: False)
#   --bbflux              compute and write the QSO broad-band fluxes in the
#                         fibermap (default: False)
#   --add-LYB             Add LYB absorption from transmision file (default:
#                         False)
#   --metals [METALS ...]
#                         list of metals to get the transmission from, if 'all'
#                         runs on all metals (default: None)
#   --metals-from-file [METALS_FROM_FILE]
#                         list of metals,'SI1260,SI1207' etc, to get from HDUs
#                         in file. Use 'all' or no argument for mock version <
#                         7.3 or final metal runs. (default: None)
#   --dla DLA             Add DLA to simulated spectra either randonmly (--dla
#                         random) or from transmision file (--dla file)
#                         (default: None)
#   --balprob BALPROB     To add BAL features with the specified probability
#                         (e.g --balprob 0.5). Expect a number between 0 and 1
#                         (default: None)
#   --no-simqso           Does not use desisim.templates.SIMQSO to generate
#                         templates, and uses desisim.templates.QSO instead.
#                         (default: False)
#   --save-continuum      Save true continum to file (default: False)
#   --save-continuum-dwave SAVE_CONTINUUM_DWAVE
#                         Delta wavelength to save true continum (default: 2)
#   --desi-footprint      select QSOs in DESI footprint (default: False)
#   --eboss               Setup footprint, number density, redshift
#                         distribution, and exposure time to generate eBOSS-like
#                         mocks (default: False)
#   --extinction          Adds Galactic extinction (default: False)
#   --no-transmission     Do not multiply continuum by transmission, use F=1
#                         everywhere (default: False)
#   --nproc NPROC         number of processors to run faster (default: 1)
#   --overwrite           rerun if spectra exists (default is skip) (default:
#                         False)
#   --nmax NMAX           Max number of QSO per input file, for debugging
#                         (default: None)
#   --save-resolution     Save full resolution in spectra file. By default only
#                         one matrix is saved in the truth file. (default:
#                         False)

# %% [markdown]
# ### We will start by running quickquasars in a single pixel, for this we define some of the required parameters. We will run it using different exposures (1,2,3,4) and have one with a very large exposure time for comparison. Also this first runs will not have any contaminant, they only have continum LYA and LYB absorption.

# %%
zmin = 1.8 # We use to add it, although it is already set as minimum in the transmission files.
nmax = 10 # maximun number of spectra to simulate in a given pixel, chosen as a small number for speedness in this tutorial.
seed=123 #this ensure reproducibility

# %%
path_mocks = '/global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0' # path to london mocks v9.0
ifile=path_mocks + '/v9.0.0/0/0/transmission-16-0.fits.gz'   #Choose one pixel to simulate the quasars. 
outdir=os.path.join(os.environ['SCRATCH'], 'mocks','quickquasar','1pix_test/')  #Where do you want to save the files.
print(outdir) #Adjuts the path if this is not where you want to store the files produced by this tutorial
# Out:
# /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/

# %%
os.makedirs(outdir, exist_ok=True)

# %%
#Run quickquasars for the different exposures, store each run a different directory to avoid overwrting.
exposures = ['1','2','3','4','1e5']
contaminant='0.0-' # Following somehow the convention in https://desi.lbl.gov/trac/wiki/LymanAlphaWG/LondonMocks/v9_quickquasars

for exp in exposures:
    if not os.path.exists(outdir +contaminant+exp):
        os.mkdir(outdir +contaminant+exp )
    specfile = outdir +contaminant+exp+'/spectra.fits'
    cmd ='quickquasars --exptime {exptime} -i {ifile} -o {outfile}  --zmin {zmin} \
    --zbest --bbflux --add-LYB --desi-footprint \
    --nmax {nmax} --seed {seed}'.format(exptime=float(exp)*1000,ifile=ifile,outfile=specfile,zmin=zmin,nmax=nmax,seed=seed)
    # !time $cmd
# Out:
# INFO:quickquasars.py:873:main: Load SIMQSO model
# WARNING:templates.py:2470:__init__: Using modified simqso.sqmodel defined in desisim.scripts.lya_simqso_model
# INFO:quickquasars.py:882:main: Load DeCAM and WISE filters for target selection sim.
# ifilename /global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0/v9.0.0/0/0/transmission-16-0.fits.gz
# INFO:quickquasars.py:220:get_healpix_info: healpix=HPXPIXEL=0
# INFO:quickquasars.py:225:get_healpix_info: nside=HPXNSIDE=16
# INFO:quickquasars.py:233:get_healpix_info: hpxnest from HPXNEST = True
# INFO:quickquasars.py:316:simulate_one_healpix: Read skewers in /global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0/v9.0.0/0/0/transmission-16-0.fits.gz, random seed = 2866
# INFO:quickquasars.py:320:simulate_one_healpix: Read transmission file /global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0/v9.0.0/0/0/transmission-16-0.fits.gz
# INFO:lya_spectra.py:114:read_lya_skewers: Added LYB from transmission file
# INFO:quickquasars.py:325:simulate_one_healpix: Add FOG to redshift with sigma 150 to quasar redshift
# INFO:quickquasars.py:368:simulate_one_healpix: Select QSOs in DESI footprint 2576 -> 2576
# INFO:quickquasars.py:394:simulate_one_healpix: Limit number of QSOs from 2576 to nmax=10 (random subsample)
# INFO:quickquasars.py:481:simulate_one_healpix: Increase wavelength range from 3470:6499 to 3329:6499 to compute magnitudes
# INFO:quickquasars.py:491:simulate_one_healpix: Increase wavelength range from 3329:6499 to 3329:55501 to compute magnitudes
# INFO:quickquasars.py:512:simulate_one_healpix: Simulate 10 QSOs with SIMQSO templates
# INFO:quickquasars.py:546:simulate_one_healpix: Resample to transmission wavelength grid
# INFO:quickquasars.py:600:simulate_one_healpix: Apply transmitted flux fraction
# INFO:quickquasars.py:632:simulate_one_healpix: Compute QSO magnitudes
# INFO:quickquasars.py:668:simulate_one_healpix: Resample to a linear wavelength grid (needed by DESI sim.)
# INFO:quickquasars.py:675:simulate_one_healpix: Simulate DESI observation and write output file
# INFO:quickspectra.py:64:sim_spectra: Starting simulation of 10 spectra
# INFO:iers.py:82:freeze_iers: Freezing IERS table used by astropy time, coordinates.
# DEBUG:simexp.py:418:simulate_spectra: loading specsim desi config desi
# DEBUG:simexp.py:422:simulate_spectra: creating specsim desi simulator
# INFO:simexp.py:444:simulate_spectra: MJD not in obsconditions, using DATE-OBS 2009-06-18T12:00:00.000
# DEBUG:simexp.py:448:simulate_spectra: obsconditions SEEING = 1.1
# DEBUG:simexp.py:448:simulate_spectra: obsconditions EXPTIME = 1000.0
# DEBUG:simexp.py:448:simulate_spectra: obsconditions AIRMASS = 1.0
# DEBUG:simexp.py:448:simulate_spectra: obsconditions MOONFRAC = 0.0
# DEBUG:simexp.py:448:simulate_spectra: obsconditions MOONALT = -60
# DEBUG:simexp.py:448:simulate_spectra: obsconditions MOONSEP = 180
# DEBUG:simexp.py:490:simulate_spectra: running simulation with fastsim fiber loss method
# DEBUG:simexp.py:496:simulate_spectra: source types: 10 qso
# INFO:spectra.py:180:write_spectra: iotime 0.061 sec to write spectra.fits at 2022-06-07T08:16:12.883685
# INFO:quickspectra.py:274:sim_spectra: Wrote /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.0-1/spectra.fits
# INFO:quickquasars.py:737:simulate_one_healpix: Added a shift of 0 km/s to the redshift
# INFO:quickquasars.py:749:simulate_one_healpix: Writing a truth file  /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.0-1/truth-16-0.fits
# INFO:quickquasars.py:797:simulate_one_healpix: Read fibermap
# INFO:fibermap.py:291:read_fibermap: iotime 0.011 sec to read spectra.fits at 2022-06-07T08:16:12.940346
# INFO:quickquasars.py:799:simulate_one_healpix: Writing a zbest file /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.0-1/zbest-16-0.fits
#
# real	0m18.059s
# user	0m15.238s
# sys	0m2.312s
# INFO:quickquasars.py:873:main: Load SIMQSO model
# WARNING:templates.py:2470:__init__: Using modified simqso.sqmodel defined in desisim.scripts.lya_simqso_model
# INFO:quickquasars.py:882:main: Load DeCAM and WISE filters for target selection sim.
# ifilename /global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0/v9.0.0/0/0/transmission-16-0.fits.gz
# INFO:quickquasars.py:220:get_healpix_info: healpix=HPXPIXEL=0
# INFO:quickquasars.py:225:get_healpix_info: nside=HPXNSIDE=16
# INFO:quickquasars.py:233:get_healpix_info: hpxnest from HPXNEST = True
# INFO:quickquasars.py:316:simulate_one_healpix: Read skewers in /global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0/v9.0.0/0/0/transmission-16-0.fits.gz, random seed = 2866
# INFO:quickquasars.py:320:simulate_one_healpix: Read transmission file /global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0/v9.0.0/0/0/transmission-16-0.fits.gz
# INFO:lya_spectra.py:114:read_lya_skewers: Added LYB from transmission file
# INFO:quickquasars.py:325:simulate_one_healpix: Add FOG to redshift with sigma 150 to quasar redshift
# INFO:quickquasars.py:368:simulate_one_healpix: Select QSOs in DESI footprint 2576 -> 2576
# INFO:quickquasars.py:394:simulate_one_healpix: Limit number of QSOs from 2576 to nmax=10 (random subsample)
# INFO:quickquasars.py:481:simulate_one_healpix: Increase wavelength range from 3470:6499 to 3329:6499 to compute magnitudes
# INFO:quickquasars.py:491:simulate_one_healpix: Increase wavelength range from 3329:6499 to 3329:55501 to compute magnitudes
# INFO:quickquasars.py:512:simulate_one_healpix: Simulate 10 QSOs with SIMQSO templates
# INFO:quickquasars.py:546:simulate_one_healpix: Resample to transmission wavelength grid
# INFO:quickquasars.py:600:simulate_one_healpix: Apply transmitted flux fraction
# INFO:quickquasars.py:632:simulate_one_healpix: Compute QSO magnitudes
# INFO:quickquasars.py:668:simulate_one_healpix: Resample to a linear wavelength grid (needed by DESI sim.)
# INFO:quickquasars.py:675:simulate_one_healpix: Simulate DESI observation and write output file
# INFO:quickspectra.py:64:sim_spectra: Starting simulation of 10 spectra
# INFO:iers.py:82:freeze_iers: Freezing IERS table used by astropy time, coordinates.
# DEBUG:simexp.py:418:simulate_spectra: loading specsim desi config desi
# DEBUG:simexp.py:422:simulate_spectra: creating specsim desi simulator
# INFO:simexp.py:444:simulate_spectra: MJD not in obsconditions, using DATE-OBS 2009-06-18T12:00:00.000
# DEBUG:simexp.py:448:simulate_spectra: obsconditions SEEING = 1.1
# DEBUG:simexp.py:448:simulate_spectra: obsconditions EXPTIME = 2000.0
# DEBUG:simexp.py:448:simulate_spectra: obsconditions AIRMASS = 1.0
# DEBUG:simexp.py:448:simulate_spectra: obsconditions MOONFRAC = 0.0
# DEBUG:simexp.py:448:simulate_spectra: obsconditions MOONALT = -60
# DEBUG:simexp.py:448:simulate_spectra: obsconditions MOONSEP = 180
# DEBUG:simexp.py:490:simulate_spectra: running simulation with fastsim fiber loss method
# DEBUG:simexp.py:496:simulate_spectra: source types: 10 qso
# INFO:spectra.py:180:write_spectra: iotime 0.059 sec to write spectra.fits at 2022-06-07T08:16:31.142846
# INFO:quickspectra.py:274:sim_spectra: Wrote /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.0-2/spectra.fits
# INFO:quickquasars.py:737:simulate_one_healpix: Added a shift of 0 km/s to the redshift
# INFO:quickquasars.py:749:simulate_one_healpix: Writing a truth file  /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.0-2/truth-16-0.fits
# INFO:quickquasars.py:797:simulate_one_healpix: Read fibermap
# INFO:fibermap.py:291:read_fibermap: iotime 0.015 sec to read spectra.fits at 2022-06-07T08:16:31.217813
# INFO:quickquasars.py:799:simulate_one_healpix: Writing a zbest file /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.0-2/zbest-16-0.fits
#
# real	0m18.431s
# user	0m16.021s
# sys	0m2.318s
# INFO:quickquasars.py:873:main: Load SIMQSO model
# WARNING:templates.py:2470:__init__: Using modified simqso.sqmodel defined in desisim.scripts.lya_simqso_model
# INFO:quickquasars.py:882:main: Load DeCAM and WISE filters for target selection sim.
# ifilename /global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0/v9.0.0/0/0/transmission-16-0.fits.gz
# INFO:quickquasars.py:220:get_healpix_info: healpix=HPXPIXEL=0
# INFO:quickquasars.py:225:get_healpix_info: nside=HPXNSIDE=16
# INFO:quickquasars.py:233:get_healpix_info: hpxnest from HPXNEST = True
# INFO:quickquasars.py:316:simulate_one_healpix: Read skewers in /global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0/v9.0.0/0/0/transmission-16-0.fits.gz, random seed = 2866
# INFO:quickquasars.py:320:simulate_one_healpix: Read transmission file /global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0/v9.0.0/0/0/transmission-16-0.fits.gz
# INFO:lya_spectra.py:114:read_lya_skewers: Added LYB from transmission file
# INFO:quickquasars.py:325:simulate_one_healpix: Add FOG to redshift with sigma 150 to quasar redshift
# INFO:quickquasars.py:368:simulate_one_healpix: Select QSOs in DESI footprint 2576 -> 2576
# INFO:quickquasars.py:394:simulate_one_healpix: Limit number of QSOs from 2576 to nmax=10 (random subsample)
# INFO:quickquasars.py:481:simulate_one_healpix: Increase wavelength range from 3470:6499 to 3329:6499 to compute magnitudes
# INFO:quickquasars.py:491:simulate_one_healpix: Increase wavelength range from 3329:6499 to 3329:55501 to compute magnitudes
# INFO:quickquasars.py:512:simulate_one_healpix: Simulate 10 QSOs with SIMQSO templates
# INFO:quickquasars.py:546:simulate_one_healpix: Resample to transmission wavelength grid
# INFO:quickquasars.py:600:simulate_one_healpix: Apply transmitted flux fraction
# INFO:quickquasars.py:632:simulate_one_healpix: Compute QSO magnitudes
# INFO:quickquasars.py:668:simulate_one_healpix: Resample to a linear wavelength grid (needed by DESI sim.)
# INFO:quickquasars.py:675:simulate_one_healpix: Simulate DESI observation and write output file
# INFO:quickspectra.py:64:sim_spectra: Starting simulation of 10 spectra
# INFO:iers.py:82:freeze_iers: Freezing IERS table used by astropy time, coordinates.
# DEBUG:simexp.py:418:simulate_spectra: loading specsim desi config desi
# DEBUG:simexp.py:422:simulate_spectra: creating specsim desi simulator
# INFO:simexp.py:444:simulate_spectra: MJD not in obsconditions, using DATE-OBS 2009-06-18T12:00:00.000
# DEBUG:simexp.py:448:simulate_spectra: obsconditions SEEING = 1.1
# DEBUG:simexp.py:448:simulate_spectra: obsconditions EXPTIME = 3000.0
# DEBUG:simexp.py:448:simulate_spectra: obsconditions AIRMASS = 1.0
# DEBUG:simexp.py:448:simulate_spectra: obsconditions MOONFRAC = 0.0
# DEBUG:simexp.py:448:simulate_spectra: obsconditions MOONALT = -60
# DEBUG:simexp.py:448:simulate_spectra: obsconditions MOONSEP = 180
# DEBUG:simexp.py:490:simulate_spectra: running simulation with fastsim fiber loss method
# DEBUG:simexp.py:496:simulate_spectra: source types: 10 qso
# INFO:spectra.py:180:write_spectra: iotime 0.058 sec to write spectra.fits at 2022-06-07T08:16:51.095613
# INFO:quickspectra.py:274:sim_spectra: Wrote /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.0-3/spectra.fits
# INFO:quickquasars.py:737:simulate_one_healpix: Added a shift of 0 km/s to the redshift
# INFO:quickquasars.py:749:simulate_one_healpix: Writing a truth file  /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.0-3/truth-16-0.fits
# INFO:quickquasars.py:797:simulate_one_healpix: Read fibermap
# INFO:fibermap.py:291:read_fibermap: iotime 0.011 sec to read spectra.fits at 2022-06-07T08:16:51.152971
# INFO:quickquasars.py:799:simulate_one_healpix: Writing a zbest file /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.0-3/zbest-16-0.fits
#
# real	0m19.671s
# user	0m16.999s
# sys	0m2.543s
# INFO:quickquasars.py:873:main: Load SIMQSO model
# WARNING:templates.py:2470:__init__: Using modified simqso.sqmodel defined in desisim.scripts.lya_simqso_model
# INFO:quickquasars.py:882:main: Load DeCAM and WISE filters for target selection sim.
# ifilename /global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0/v9.0.0/0/0/transmission-16-0.fits.gz
# INFO:quickquasars.py:220:get_healpix_info: healpix=HPXPIXEL=0
# INFO:quickquasars.py:225:get_healpix_info: nside=HPXNSIDE=16
# INFO:quickquasars.py:233:get_healpix_info: hpxnest from HPXNEST = True
# INFO:quickquasars.py:316:simulate_one_healpix: Read skewers in /global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0/v9.0.0/0/0/transmission-16-0.fits.gz, random seed = 2866
# INFO:quickquasars.py:320:simulate_one_healpix: Read transmission file /global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0/v9.0.0/0/0/transmission-16-0.fits.gz
# INFO:lya_spectra.py:114:read_lya_skewers: Added LYB from transmission file
# INFO:quickquasars.py:325:simulate_one_healpix: Add FOG to redshift with sigma 150 to quasar redshift
# INFO:quickquasars.py:368:simulate_one_healpix: Select QSOs in DESI footprint 2576 -> 2576
# INFO:quickquasars.py:394:simulate_one_healpix: Limit number of QSOs from 2576 to nmax=10 (random subsample)
# INFO:quickquasars.py:481:simulate_one_healpix: Increase wavelength range from 3470:6499 to 3329:6499 to compute magnitudes
# INFO:quickquasars.py:491:simulate_one_healpix: Increase wavelength range from 3329:6499 to 3329:55501 to compute magnitudes
# INFO:quickquasars.py:512:simulate_one_healpix: Simulate 10 QSOs with SIMQSO templates
# INFO:quickquasars.py:546:simulate_one_healpix: Resample to transmission wavelength grid
# INFO:quickquasars.py:600:simulate_one_healpix: Apply transmitted flux fraction
# INFO:quickquasars.py:632:simulate_one_healpix: Compute QSO magnitudes
# INFO:quickquasars.py:668:simulate_one_healpix: Resample to a linear wavelength grid (needed by DESI sim.)
# INFO:quickquasars.py:675:simulate_one_healpix: Simulate DESI observation and write output file
# INFO:quickspectra.py:64:sim_spectra: Starting simulation of 10 spectra
# INFO:iers.py:82:freeze_iers: Freezing IERS table used by astropy time, coordinates.
# DEBUG:simexp.py:418:simulate_spectra: loading specsim desi config desi
# DEBUG:simexp.py:422:simulate_spectra: creating specsim desi simulator
# INFO:simexp.py:444:simulate_spectra: MJD not in obsconditions, using DATE-OBS 2009-06-18T12:00:00.000
# DEBUG:simexp.py:448:simulate_spectra: obsconditions SEEING = 1.1
# DEBUG:simexp.py:448:simulate_spectra: obsconditions EXPTIME = 4000.0
# DEBUG:simexp.py:448:simulate_spectra: obsconditions AIRMASS = 1.0
# DEBUG:simexp.py:448:simulate_spectra: obsconditions MOONFRAC = 0.0
# DEBUG:simexp.py:448:simulate_spectra: obsconditions MOONALT = -60
# DEBUG:simexp.py:448:simulate_spectra: obsconditions MOONSEP = 180
# DEBUG:simexp.py:490:simulate_spectra: running simulation with fastsim fiber loss method
# DEBUG:simexp.py:496:simulate_spectra: source types: 10 qso
# INFO:spectra.py:180:write_spectra: iotime 0.061 sec to write spectra.fits at 2022-06-07T08:17:07.767819
# INFO:quickspectra.py:274:sim_spectra: Wrote /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.0-4/spectra.fits
# INFO:quickquasars.py:737:simulate_one_healpix: Added a shift of 0 km/s to the redshift
# INFO:quickquasars.py:749:simulate_one_healpix: Writing a truth file  /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.0-4/truth-16-0.fits
# INFO:quickquasars.py:797:simulate_one_healpix: Read fibermap
# INFO:fibermap.py:291:read_fibermap: iotime 0.010 sec to read spectra.fits at 2022-06-07T08:17:07.840021
# INFO:quickquasars.py:799:simulate_one_healpix: Writing a zbest file /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.0-4/zbest-16-0.fits
#
# real	0m16.404s
# user	0m14.156s
# sys	0m2.158s
# INFO:quickquasars.py:873:main: Load SIMQSO model
# WARNING:templates.py:2470:__init__: Using modified simqso.sqmodel defined in desisim.scripts.lya_simqso_model
# INFO:quickquasars.py:882:main: Load DeCAM and WISE filters for target selection sim.
# ifilename /global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0/v9.0.0/0/0/transmission-16-0.fits.gz
# INFO:quickquasars.py:220:get_healpix_info: healpix=HPXPIXEL=0
# INFO:quickquasars.py:225:get_healpix_info: nside=HPXNSIDE=16
# INFO:quickquasars.py:233:get_healpix_info: hpxnest from HPXNEST = True
# INFO:quickquasars.py:316:simulate_one_healpix: Read skewers in /global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0/v9.0.0/0/0/transmission-16-0.fits.gz, random seed = 2866
# INFO:quickquasars.py:320:simulate_one_healpix: Read transmission file /global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0/v9.0.0/0/0/transmission-16-0.fits.gz
# INFO:lya_spectra.py:114:read_lya_skewers: Added LYB from transmission file
# INFO:quickquasars.py:325:simulate_one_healpix: Add FOG to redshift with sigma 150 to quasar redshift
# INFO:quickquasars.py:368:simulate_one_healpix: Select QSOs in DESI footprint 2576 -> 2576
# INFO:quickquasars.py:394:simulate_one_healpix: Limit number of QSOs from 2576 to nmax=10 (random subsample)
# INFO:quickquasars.py:481:simulate_one_healpix: Increase wavelength range from 3470:6499 to 3329:6499 to compute magnitudes
# INFO:quickquasars.py:491:simulate_one_healpix: Increase wavelength range from 3329:6499 to 3329:55501 to compute magnitudes
# INFO:quickquasars.py:512:simulate_one_healpix: Simulate 10 QSOs with SIMQSO templates
# INFO:quickquasars.py:546:simulate_one_healpix: Resample to transmission wavelength grid
# INFO:quickquasars.py:600:simulate_one_healpix: Apply transmitted flux fraction
# INFO:quickquasars.py:632:simulate_one_healpix: Compute QSO magnitudes
# INFO:quickquasars.py:668:simulate_one_healpix: Resample to a linear wavelength grid (needed by DESI sim.)
# INFO:quickquasars.py:675:simulate_one_healpix: Simulate DESI observation and write output file
# INFO:quickspectra.py:64:sim_spectra: Starting simulation of 10 spectra
# INFO:iers.py:82:freeze_iers: Freezing IERS table used by astropy time, coordinates.
# DEBUG:simexp.py:418:simulate_spectra: loading specsim desi config desi
# DEBUG:simexp.py:422:simulate_spectra: creating specsim desi simulator
# INFO:simexp.py:444:simulate_spectra: MJD not in obsconditions, using DATE-OBS 2009-06-18T12:00:00.000
# DEBUG:simexp.py:448:simulate_spectra: obsconditions SEEING = 1.1
# DEBUG:simexp.py:448:simulate_spectra: obsconditions EXPTIME = 100000000.0
# DEBUG:simexp.py:448:simulate_spectra: obsconditions AIRMASS = 1.0
# DEBUG:simexp.py:448:simulate_spectra: obsconditions MOONFRAC = 0.0
# DEBUG:simexp.py:448:simulate_spectra: obsconditions MOONALT = -60
# DEBUG:simexp.py:448:simulate_spectra: obsconditions MOONSEP = 180
# DEBUG:simexp.py:490:simulate_spectra: running simulation with fastsim fiber loss method
# DEBUG:simexp.py:496:simulate_spectra: source types: 10 qso
# INFO:spectra.py:180:write_spectra: iotime 0.360 sec to write spectra.fits at 2022-06-07T08:17:24.889822
# INFO:quickspectra.py:274:sim_spectra: Wrote /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.0-1e5/spectra.fits
# INFO:quickquasars.py:737:simulate_one_healpix: Added a shift of 0 km/s to the redshift
# INFO:quickquasars.py:749:simulate_one_healpix: Writing a truth file  /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.0-1e5/truth-16-0.fits
# INFO:quickquasars.py:797:simulate_one_healpix: Read fibermap
# INFO:fibermap.py:291:read_fibermap: iotime 0.011 sec to read spectra.fits at 2022-06-07T08:17:24.949875
# INFO:quickquasars.py:799:simulate_one_healpix: Writing a zbest file /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.0-1e5/zbest-16-0.fits
#
# real	0m16.966s
# user	0m14.372s
# sys	0m2.212s

# %% [markdown]
# ### Now lets comapare the spectra we got from each simulation

# %%
dump = []
for exp in exposures:
    dump.append(outdir +'0.0-'+exp)
path_highexp = dump[-1]
del(dump[-1])
dump.sort()
print(path_highexp)
# Out:
# /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.0-1e5

# %%
spec = fitsio.FITS(path_highexp+'/spectra.fits')
spec
# Out:
#   file: /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.0-1e5/spectra.fits
#   mode: READONLY
#   extnum hdutype         hduname[v]
#   0      IMAGE_HDU
#   1      BINARY_TBL      FIBERMAP
#   2      IMAGE_HDU       B_WAVELENGTH
#   3      IMAGE_HDU       B_FLUX
#   4      IMAGE_HDU       B_IVAR
#   5      IMAGE_HDU       B_MASK
#   6      IMAGE_HDU       R_WAVELENGTH
#   7      IMAGE_HDU       R_FLUX
#   8      IMAGE_HDU       R_IVAR
#   9      IMAGE_HDU       R_MASK
#   10     IMAGE_HDU       Z_WAVELENGTH
#   11     IMAGE_HDU       Z_FLUX
#   12     IMAGE_HDU       Z_IVAR
#   13     IMAGE_HDU       Z_MASK

# %%
truth = fitsio.FITS(path_highexp + '/truth-16-0.fits')

# %%
spectra_highexp = desispec.io.read_spectra(path_highexp+'/spectra.fits')
# Out:
# INFO:spectra.py:285:read_spectra: iotime 0.060 sec to read spectra.fits at 2022-06-07T08:17:25.760846

# %%
index = 4
plt.figure(figsize=(10,5),dpi=100)
for i in range(len(dump)):
    plt.subplot(221+i)
    exposure = dump[i].split('/0.0-')[-1]
    spectra= desispec.io.read_spectra(dump[i]+'/spectra.fits')
    plotspec(spectra,index,label='Exposure = '+exposure)
    plotspec(spectra_highexp,index,color=['k','k','k'],label='Noisless')
    z_obj = truth[1]['Z'][index]
    lya = draw_obsline(1215.67,z_obj)
    lyb = draw_obsline(1025.722,z_obj)
    civ = draw_obsline(1549.48,z_obj)
    #mgii = draw_obsline(2799.117,z_obj)
    plt.axvline(lya,color='g')
    plt.axvline(lyb,color='g')
    plt.axvline(civ,color='g')
    #plt.axvline(mgii,color='g')
    #plt.xlim(3500,5000)
plt.subplots_adjust(hspace=0.3,wspace=.2)
# Out:
# INFO:spectra.py:285:read_spectra: iotime 0.049 sec to read spectra.fits at 2022-06-07T08:17:25.846376
# INFO:spectra.py:285:read_spectra: iotime 0.050 sec to read spectra.fits at 2022-06-07T08:17:25.935861
# INFO:spectra.py:285:read_spectra: iotime 0.052 sec to read spectra.fits at 2022-06-07T08:17:26.023274
# INFO:spectra.py:285:read_spectra: iotime 0.058 sec to read spectra.fits at 2022-06-07T08:17:26.114560

# %% [markdown]
# ### We can compare the differences as well

# %%
index = 4
plt.figure(figsize=(10,5),dpi=100)
for i in range(len(dump)):
    plt.subplot(221+i)
    exposure = dump[i].split('/')[-1]
    spectra= desispec.io.read_spectra(dump[i]+'/spectra.fits')
    plotspec_ratio(spectra,spectra_highexp,index,label='Exposure= '+exposure)
    #plt.xlim(3500,4300)
    plt.ylim(-5,5)
plt.subplots_adjust(hspace=0.3,wspace=.2)
# Out:
# INFO:spectra.py:285:read_spectra: iotime 0.051 sec to read spectra.fits at 2022-06-07T08:17:27.272711
# INFO:spectra.py:285:read_spectra: iotime 0.047 sec to read spectra.fits at 2022-06-07T08:17:27.344865
# INFO:spectra.py:285:read_spectra: iotime 0.049 sec to read spectra.fits at 2022-06-07T08:17:27.416352
# INFO:spectra.py:285:read_spectra: iotime 0.052 sec to read spectra.fits at 2022-06-07T08:17:27.492547

# %% [markdown]
# ## Lets look at the the other files that were produced: zbest.fits and truth.fits

# %% [markdown]
# #### The "zbest" files are fake redshift catalogs for the simulated spectra. By default it is conformed with the true redshift but we can make it more realistic by adding some errors with the following flags:
#
#
# --sigma_kms_fog
#
# --gamma_kms_zfit
#
# --shift_kms_los

# %%
data_zbest = fitsio.FITS(path_highexp+'/zbest-16-0.fits')

# %%
data_zbest[1]
# Out:
#   file: /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.0-1e5/zbest-16-0.fits
#   extension: 1
#   type: BINARY_TBL
#   extname: ZBEST
#   rows: 10
#   column info:
#     CHI2                f8
#     COEFF               f8  array[4]
#     Z                   f8
#     ZERR                f8
#     ZWARN               i8
#     SPECTYPE           S96
#     SUBTYPE            S16
#     TARGETID            i8
#     DELTACHI2           f8
#     BRICKNAME           S8

# %% [markdown]
# #### The "Truth" files stores all the information regarding the templates used to construct the spectra, as well as the magnitude of the objects, true redshift, if the spectra has contaminats, etc.

# %%
data_truth = fitsio.FITS(path_highexp+'/truth-16-0.fits')

# %%
data_truth
# Out:
#   file: /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.0-1e5/truth-16-0.fits
#   mode: READONLY
#   extnum hdutype         hduname[v]
#   0      IMAGE_HDU
#   1      BINARY_TBL      TRUTH
#   2      BINARY_TBL      TRUTH_QSO
#   3      IMAGE_HDU       B_RESOLUTION
#   4      IMAGE_HDU       R_RESOLUTION
#   5      IMAGE_HDU       Z_RESOLUTION

# %% [markdown]
# ## So far the spectra has no contaminants, so lets add some. We will start with DLA's

# %% [markdown]
# #### There is two ways to add DLA's, one is at random redshifts and column density, and the other is by what is already stored in the transmission file. In this tutorial we will use the DLAs specified in the transmission file

# %%
exp='4'
contaminant='0.1DLA-'
outdir_dla=outdir +contaminant+exp
os.makedirs(outdir +contaminant+exp,exist_ok=True)
        
specfile = outdir +contaminant + exp +'/spectra.fits'
cmd ='quickquasars  -i {ifile} -o {outfile}  --zmin {zmin} --exptime {exptime}\
    --zbest --bbflux --add-LYB --desi-footprint \
    --nmax {nmax} --seed {seed} --dla file'.format(exptime=float(exp)*1000,ifile=ifile,outfile=specfile,zmin=zmin,nmax=nmax,seed=seed)

# !$cmd
# Out:
# INFO:quickquasars.py:873:main: Load SIMQSO model
# WARNING:templates.py:2470:__init__: Using modified simqso.sqmodel defined in desisim.scripts.lya_simqso_model
# INFO:quickquasars.py:882:main: Load DeCAM and WISE filters for target selection sim.
# ifilename /global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0/v9.0.0/0/0/transmission-16-0.fits.gz
# INFO:quickquasars.py:220:get_healpix_info: healpix=HPXPIXEL=0
# INFO:quickquasars.py:225:get_healpix_info: nside=HPXNSIDE=16
# INFO:quickquasars.py:233:get_healpix_info: hpxnest from HPXNEST = True
# INFO:quickquasars.py:316:simulate_one_healpix: Read skewers in /global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0/v9.0.0/0/0/transmission-16-0.fits.gz, random seed = 2866
# INFO:quickquasars.py:320:simulate_one_healpix: Read transmission file /global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0/v9.0.0/0/0/transmission-16-0.fits.gz
# INFO:lya_spectra.py:114:read_lya_skewers: Added LYB from transmission file
# INFO:lya_spectra.py:162:read_lya_skewers: Read DLAs from transmision file
# INFO:quickquasars.py:325:simulate_one_healpix: Add FOG to redshift with sigma 150 to quasar redshift
# INFO:quickquasars.py:368:simulate_one_healpix: Select QSOs in DESI footprint 2576 -> 2576
# INFO:quickquasars.py:394:simulate_one_healpix: Limit number of QSOs from 2576 to nmax=10 (random subsample)
# INFO:quickquasars.py:416:simulate_one_healpix: Adding DLAs from transmission file
# INFO:quickquasars.py:459:simulate_one_healpix: Added 3 DLAs
# INFO:quickquasars.py:470:simulate_one_healpix: DLA metadata to be saved in /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.1DLA-4/truth-16-0.fits
# INFO:quickquasars.py:481:simulate_one_healpix: Increase wavelength range from 3470:6499 to 3329:6499 to compute magnitudes
# INFO:quickquasars.py:491:simulate_one_healpix: Increase wavelength range from 3329:6499 to 3329:55501 to compute magnitudes
# INFO:quickquasars.py:512:simulate_one_healpix: Simulate 10 QSOs with SIMQSO templates
# INFO:quickquasars.py:546:simulate_one_healpix: Resample to transmission wavelength grid
# INFO:quickquasars.py:600:simulate_one_healpix: Apply transmitted flux fraction
# INFO:quickquasars.py:632:simulate_one_healpix: Compute QSO magnitudes
# INFO:quickquasars.py:668:simulate_one_healpix: Resample to a linear wavelength grid (needed by DESI sim.)
# INFO:quickquasars.py:675:simulate_one_healpix: Simulate DESI observation and write output file
# INFO:quickspectra.py:64:sim_spectra: Starting simulation of 10 spectra
# INFO:iers.py:82:freeze_iers: Freezing IERS table used by astropy time, coordinates.
# DEBUG:simexp.py:418:simulate_spectra: loading specsim desi config desi
# DEBUG:simexp.py:422:simulate_spectra: creating specsim desi simulator
# INFO:simexp.py:444:simulate_spectra: MJD not in obsconditions, using DATE-OBS 2009-06-18T12:00:00.000
# DEBUG:simexp.py:448:simulate_spectra: obsconditions SEEING = 1.1
# DEBUG:simexp.py:448:simulate_spectra: obsconditions EXPTIME = 4000.0
# DEBUG:simexp.py:448:simulate_spectra: obsconditions AIRMASS = 1.0
# DEBUG:simexp.py:448:simulate_spectra: obsconditions MOONFRAC = 0.0
# DEBUG:simexp.py:448:simulate_spectra: obsconditions MOONALT = -60
# DEBUG:simexp.py:448:simulate_spectra: obsconditions MOONSEP = 180
# DEBUG:simexp.py:490:simulate_spectra: running simulation with fastsim fiber loss method
# DEBUG:simexp.py:496:simulate_spectra: source types: 10 qso
# INFO:spectra.py:180:write_spectra: iotime 0.088 sec to write spectra.fits at 2022-06-07T08:17:44.230390
# INFO:quickspectra.py:274:sim_spectra: Wrote /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.1DLA-4/spectra.fits
# INFO:quickquasars.py:737:simulate_one_healpix: Added a shift of 0 km/s to the redshift
# INFO:quickquasars.py:749:simulate_one_healpix: Writing a truth file  /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.1DLA-4/truth-16-0.fits
# INFO:quickquasars.py:797:simulate_one_healpix: Read fibermap
# INFO:fibermap.py:291:read_fibermap: iotime 0.011 sec to read spectra.fits at 2022-06-07T08:17:44.294329
# INFO:quickquasars.py:799:simulate_one_healpix: Writing a zbest file /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.1DLA-4/zbest-16-0.fits

# %%
spectra_dla = desispec.io.read_spectra(outdir_dla +'/spectra.fits')
spectra_4exp = desispec.io.read_spectra(outdir + '0.0-4/spectra.fits')
# Out:
# INFO:spectra.py:285:read_spectra: iotime 0.084 sec to read spectra.fits at 2022-06-07T08:17:45.090949
# INFO:spectra.py:285:read_spectra: iotime 0.064 sec to read spectra.fits at 2022-06-07T08:17:45.164560

# %%
truth_dla = fitsio.FITS(outdir_dla+'/truth-16-0.fits')

# %%
truth_dla[3]['TARGETID'][:]
# Out:
# array([115432, 112574, 113645])

# %%
mask = np.isin(truth_dla[1]['TARGETID'][:],truth_dla[3]['TARGETID'][:])

# %%
index = np.arange(nmax)
index = index[mask]
plt.figure(figsize=(10,5),dpi=100)
for i in range(3):
    plt.subplot(221+i)
    plotspec(spectra_4exp,index[i],color=['b','b','b'],label='no DLA')
    plotspec(spectra_dla,index[i],color=['k','k','k'],label=' with DLA')
    plt.xlim(3500,6000) #Make a zoom to see the differences
plt.subplots_adjust(hspace=0.3,wspace=.2)

# %%
plt.figure(figsize=(10,5),dpi=100)
for i in range(3):
    plt.subplot(221+i)
    plotspec_diff(spectra_dla,spectra_4exp,index[i])
    plt.xlim(3500,4000)
plt.subplots_adjust(hspace=0.3,wspace=.2)

# %% [markdown]
# ## Next, lets add BALs

# %%
exp='4'
contaminant='0.1BAL-'
outdir_bal=outdir +contaminant+exp
os.makedirs(outdir_bal,exist_ok=True)

specfile = outdir +contaminant + exp +'/spectra.fits'
cmd ='quickquasars  -i {ifile} -o {outfile}  --zmin {zmin} --exptime {exptime}\
    --zbest --bbflux --add-LYB --desi-footprint \
    --nmax {nmax} --seed {seed} --balprob 0.5'.format(exptime=float(exp)*1000,ifile=ifile,outfile=specfile,zmin=zmin,nmax=nmax,seed=seed)
# !$cmd
# Out:
# INFO:quickquasars.py:873:main: Load SIMQSO model
# WARNING:templates.py:2470:__init__: Using modified simqso.sqmodel defined in desisim.scripts.lya_simqso_model
# INFO:quickquasars.py:882:main: Load DeCAM and WISE filters for target selection sim.
# INFO:io.py:971:read_basis_templates: Reading /global/cfs/cdirs/desi/spectro/templates/basis_templates/v3.2/bal_templates_v3.0.fits
# ifilename /global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0/v9.0.0/0/0/transmission-16-0.fits.gz
# INFO:quickquasars.py:220:get_healpix_info: healpix=HPXPIXEL=0
# INFO:quickquasars.py:225:get_healpix_info: nside=HPXNSIDE=16
# INFO:quickquasars.py:233:get_healpix_info: hpxnest from HPXNEST = True
# INFO:quickquasars.py:316:simulate_one_healpix: Read skewers in /global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0/v9.0.0/0/0/transmission-16-0.fits.gz, random seed = 2866
# INFO:quickquasars.py:320:simulate_one_healpix: Read transmission file /global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0/v9.0.0/0/0/transmission-16-0.fits.gz
# INFO:lya_spectra.py:114:read_lya_skewers: Added LYB from transmission file
# INFO:quickquasars.py:325:simulate_one_healpix: Add FOG to redshift with sigma 150 to quasar redshift
# INFO:quickquasars.py:368:simulate_one_healpix: Select QSOs in DESI footprint 2576 -> 2576
# INFO:quickquasars.py:394:simulate_one_healpix: Limit number of QSOs from 2576 to nmax=10 (random subsample)
# INFO:quickquasars.py:481:simulate_one_healpix: Increase wavelength range from 3470:6499 to 3329:6499 to compute magnitudes
# INFO:quickquasars.py:491:simulate_one_healpix: Increase wavelength range from 3329:6499 to 3329:55501 to compute magnitudes
# INFO:quickquasars.py:512:simulate_one_healpix: Simulate 10 QSOs with SIMQSO templates
# INFO:quickquasars.py:546:simulate_one_healpix: Resample to transmission wavelength grid
# INFO:quickquasars.py:579:simulate_one_healpix: Adding BALs with probability 0.5
# INFO:quickquasars.py:600:simulate_one_healpix: Apply transmitted flux fraction
# INFO:quickquasars.py:632:simulate_one_healpix: Compute QSO magnitudes
# INFO:quickquasars.py:668:simulate_one_healpix: Resample to a linear wavelength grid (needed by DESI sim.)
# INFO:quickquasars.py:675:simulate_one_healpix: Simulate DESI observation and write output file
# INFO:quickspectra.py:64:sim_spectra: Starting simulation of 10 spectra
# INFO:iers.py:82:freeze_iers: Freezing IERS table used by astropy time, coordinates.
# DEBUG:simexp.py:418:simulate_spectra: loading specsim desi config desi
# DEBUG:simexp.py:422:simulate_spectra: creating specsim desi simulator
# INFO:simexp.py:444:simulate_spectra: MJD not in obsconditions, using DATE-OBS 2009-06-18T12:00:00.000
# DEBUG:simexp.py:448:simulate_spectra: obsconditions SEEING = 1.1
# DEBUG:simexp.py:448:simulate_spectra: obsconditions EXPTIME = 4000.0
# DEBUG:simexp.py:448:simulate_spectra: obsconditions AIRMASS = 1.0
# DEBUG:simexp.py:448:simulate_spectra: obsconditions MOONFRAC = 0.0
# DEBUG:simexp.py:448:simulate_spectra: obsconditions MOONALT = -60
# DEBUG:simexp.py:448:simulate_spectra: obsconditions MOONSEP = 180
# DEBUG:simexp.py:490:simulate_spectra: running simulation with fastsim fiber loss method
# DEBUG:simexp.py:496:simulate_spectra: source types: 10 qso
# INFO:spectra.py:180:write_spectra: iotime 0.060 sec to write spectra.fits at 2022-06-07T08:18:02.875399
# INFO:quickspectra.py:274:sim_spectra: Wrote /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.1BAL-4/spectra.fits
# INFO:quickquasars.py:737:simulate_one_healpix: Added a shift of 0 km/s to the redshift
# INFO:quickquasars.py:749:simulate_one_healpix: Writing a truth file  /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.1BAL-4/truth-16-0.fits
# INFO:quickquasars.py:797:simulate_one_healpix: Read fibermap
# INFO:fibermap.py:291:read_fibermap: iotime 0.012 sec to read spectra.fits at 2022-06-07T08:18:02.942067
# INFO:quickquasars.py:799:simulate_one_healpix: Writing a zbest file /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.1BAL-4/zbest-16-0.fits

# %%
truth_bal = fitsio.FITS(outdir_bal+'/truth-16-0.fits')
mask = np.isin(truth_bal[1]['TARGETID'][:],truth_bal[3]['TARGETID'][:])
index = np.arange(nmax)
index = index[mask]

# %%
spectra_bal = desispec.io.read_spectra(outdir_bal +'/spectra.fits')
plt.figure(figsize=(10,5),dpi=100)
for i in range(4):
    plt.subplot(221+i)
    plotspec(spectra_4exp,index[i],color=['b','b','b'],label='no BALs')
    plotspec(spectra_bal,index[i],color=['k','k','k'],label=' with BALs')
    plt.xlim(3500,6000)
plt.subplots_adjust(hspace=0.3,wspace=.2)
# Out:
# INFO:spectra.py:285:read_spectra: iotime 0.070 sec to read spectra.fits at 2022-06-07T08:18:03.788066

# %%
plt.figure(figsize=(10,5),dpi=100)
for i in range(4):
    plt.subplot(221+i)
    plotspec_diff(spectra_bal,spectra_4exp,index[i])
    plt.xlim(3500,6000)
plt.subplots_adjust(hspace=0.3,wspace=.2)

# %% [markdown]
# # Finally, we can also add metals

# %%
exp='4'
contaminant='0.1MET-'
outdir_metal=outdir +contaminant+exp
os.makedirs(outdir_metal,exist_ok=True)
specfile = outdir_metal+'/spectra.fits'
cmd ='quickquasars --exptime {exptime} -i {ifile} -o {outfile}  --zmin {zmin} \
    --zbest --bbflux --add-LYB --desi-footprint \
     --nmax {nmax} --seed {seed} --metals-from-file'.format(exptime=float(exp)*1000,ifile=ifile,outfile=specfile,zmin=zmin,nmax=nmax,seed=seed)
# !time $cmd
# Out:
# INFO:quickquasars.py:873:main: Load SIMQSO model
# WARNING:templates.py:2470:__init__: Using modified simqso.sqmodel defined in desisim.scripts.lya_simqso_model
# INFO:quickquasars.py:882:main: Load DeCAM and WISE filters for target selection sim.
# ifilename /global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0/v9.0.0/0/0/transmission-16-0.fits.gz
# INFO:quickquasars.py:220:get_healpix_info: healpix=HPXPIXEL=0
# INFO:quickquasars.py:225:get_healpix_info: nside=HPXNSIDE=16
# INFO:quickquasars.py:233:get_healpix_info: hpxnest from HPXNEST = True
# INFO:quickquasars.py:316:simulate_one_healpix: Read skewers in /global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0/v9.0.0/0/0/transmission-16-0.fits.gz, random seed = 2866
# INFO:quickquasars.py:320:simulate_one_healpix: Read transmission file /global/cfs/projectdirs/desi/mocks/lya_forest/london/v9.0/v9.0.0/0/0/transmission-16-0.fits.gz
# INFO:lya_spectra.py:114:read_lya_skewers: Added LYB from transmission file
# INFO:lya_spectra.py:128:read_lya_skewers: Added F_Metals from transmision file
# INFO:quickquasars.py:325:simulate_one_healpix: Add FOG to redshift with sigma 150 to quasar redshift
# INFO:quickquasars.py:368:simulate_one_healpix: Select QSOs in DESI footprint 2576 -> 2576
# INFO:quickquasars.py:394:simulate_one_healpix: Limit number of QSOs from 2576 to nmax=10 (random subsample)
# INFO:quickquasars.py:481:simulate_one_healpix: Increase wavelength range from 3470:6499 to 3329:6499 to compute magnitudes
# INFO:quickquasars.py:491:simulate_one_healpix: Increase wavelength range from 3329:6499 to 3329:55501 to compute magnitudes
# INFO:quickquasars.py:512:simulate_one_healpix: Simulate 10 QSOs with SIMQSO templates
# INFO:quickquasars.py:546:simulate_one_healpix: Resample to transmission wavelength grid
# INFO:quickquasars.py:600:simulate_one_healpix: Apply transmitted flux fraction
# INFO:quickquasars.py:632:simulate_one_healpix: Compute QSO magnitudes
# INFO:quickquasars.py:668:simulate_one_healpix: Resample to a linear wavelength grid (needed by DESI sim.)
# INFO:quickquasars.py:675:simulate_one_healpix: Simulate DESI observation and write output file
# INFO:quickspectra.py:64:sim_spectra: Starting simulation of 10 spectra
# INFO:iers.py:82:freeze_iers: Freezing IERS table used by astropy time, coordinates.
# DEBUG:simexp.py:418:simulate_spectra: loading specsim desi config desi
# DEBUG:simexp.py:422:simulate_spectra: creating specsim desi simulator
# INFO:simexp.py:444:simulate_spectra: MJD not in obsconditions, using DATE-OBS 2009-06-18T12:00:00.000
# DEBUG:simexp.py:448:simulate_spectra: obsconditions SEEING = 1.1
# DEBUG:simexp.py:448:simulate_spectra: obsconditions EXPTIME = 4000.0
# DEBUG:simexp.py:448:simulate_spectra: obsconditions AIRMASS = 1.0
# DEBUG:simexp.py:448:simulate_spectra: obsconditions MOONFRAC = 0.0
# DEBUG:simexp.py:448:simulate_spectra: obsconditions MOONALT = -60
# DEBUG:simexp.py:448:simulate_spectra: obsconditions MOONSEP = 180
# DEBUG:simexp.py:490:simulate_spectra: running simulation with fastsim fiber loss method
# DEBUG:simexp.py:496:simulate_spectra: source types: 10 qso
# INFO:spectra.py:180:write_spectra: iotime 0.058 sec to write spectra.fits at 2022-06-07T08:18:21.597761
# INFO:quickspectra.py:274:sim_spectra: Wrote /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.1MET-4/spectra.fits
# INFO:quickquasars.py:737:simulate_one_healpix: Added a shift of 0 km/s to the redshift
# INFO:quickquasars.py:749:simulate_one_healpix: Writing a truth file  /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.1MET-4/truth-16-0.fits
# INFO:quickquasars.py:797:simulate_one_healpix: Read fibermap
# INFO:fibermap.py:291:read_fibermap: iotime 0.012 sec to read spectra.fits at 2022-06-07T08:18:21.659923
# INFO:quickquasars.py:799:simulate_one_healpix: Writing a zbest file /global/cscratch1/sd/forero/mocks/quickquasar/1pix_test/0.1MET-4/zbest-16-0.fits
#
# real	0m17.192s
# user	0m14.625s
# sys	0m2.358s

# %%
spectra_metals = desispec.io.read_spectra(outdir_metal +'/spectra.fits')
plt.figure(figsize=(10,5),dpi=100)
for i in range(4):
    plt.subplot(221+i)
    plotspec(spectra_4exp,i,color=['b','b','b'],label='no metals')
    plotspec(spectra_metals,i,color=['k','k','k'],label=' with metals')
    plt.xlim(3500,4500)
plt.subplots_adjust(hspace=0.3,wspace=.2)
# Out:
# INFO:spectra.py:285:read_spectra: iotime 0.048 sec to read spectra.fits at 2022-06-07T08:18:22.633927

# %%
plt.figure(figsize=(10,5),dpi=100)
for i in range(4):
    plt.subplot(221+i)
    plotspec_ratio(spectra_metals,spectra_4exp,i)
    plt.ylabel('Spectra ratio')
    plt.xlim(3500,4500)
    #plt.ylim(0.8,1.01)
plt.subplots_adjust(hspace=0.3,wspace=.2)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## As stated at the begining, all this has been for a sinlge pixel but we can also run a quickquasar simulation for the full DESI footprint. For this, lets take a look and run to the script quickquasars.sh

# %% [markdown]
#  ## Now that we have a bigger quickquasar run, we can stack the outputs for each pixel into a sinlge catalog

# %%
mock_path = os.path.join(os.environ['SCRATCH'], 'mocks','quickquasar')
out_zcat = mock_path+'/tutorial-0.3-4/'

# %%
cmd='desi_zcatalog -i {ipath} -o {outfile} --fibermap'.format(ipath=out_zcat+'/spectra-16/',outfile=out_zcat+'zcat.fits')
if not os.path.isfile(out_zcat+'zcat.fits'):
    # !time $cmd
else:
    print('zcat.fits already exist!')
# Out:
# usage: desi_zcatalog [-h] [-i INDIR] [-o OUTFILE] [--minimal] [-t TILES]
#                      [--prefix PREFIX] [-g GROUP] [--header [HEADER ...]]
#                      [--patch-missing-ivar-w12]
# desi_zcatalog: error: unrecognized arguments: --fibermap
#
# real	0m3.049s
# user	0m2.089s
# sys	0m0.859s

# %%
zcat = fitsio.FITS(out_zcat+'/zcat.fits')
zcat
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_36114/3641939110.py in <module>
# ----> 1 zcat = fitsio.FITS(out_zcat+'/zcat.fits')
#       2 zcat
#
# /global/common/software/desi/cori/desiconda/20211217-2.0.0/conda/lib/python3.9/site-packages/fitsio/fitslib.py in __init__(self, filename, mode, lower, upper, trim_strings, vstorage, case_sensitive, iter_row_buffer, write_bitcols, ignore_empty, verbose, clobber, **keys)
#     518
#     519         self._did_create = (create == 1)
# --> 520         self._FITS = _fitsio_wrap.FITS(filename, self.intmode, create)
#     521
#     522     def close(self):
#
# OSError: FITSIO status = 104: could not open the named file
# failed to find or open the following file: (ffopen)
# /global/cscratch1/sd/forero/mocks/quickquasar/tutorial-0.3-4//zcat.fits

# %%
zcat[1]

# %% [markdown]
# # To finish this part of the tutorial create some QA plots

# %% [markdown]
# #### We can look at the redshift distribution of the zcatalog and compare to the expected one.

# %%
## Retrive the expected distribution as function of redshift and magnitude, and define some functions useful for plotting them. Some code was borrowed/adapted from https://github.com/dkirkby/ArgonneLymanAlpha/blob/master/notebooks/SampleProperties.ipynb

from astropy.table import Table,Column

def bin_index(bin_centers, low_edge):
    """Find the index of the bin with the specified low edge, where bins is an array of equally-spaced bin centers.
    """
    delta = bin_centers[1] - bin_centers[0]
    min_value = bin_centers[0] - 0.5 * delta
    index = int(round((low_edge - min_value) / delta))
    if abs((low_edge - min_value) / delta - index) > 1e-5:
        raise ValueError('low_edge = {} is not aligned with specified bins.'.format(low_edge))
    return index

def marginal_mag(magbin, zbin, nqso, z_min=0.):
    """Tabulate the marginal distribution of QSOs per sq.deg. per (g or r) magnitude bin with z > z_min.
    """
    cut_index = bin_index(zbin, z_min)
    return magbin, np.sum(nqso[:, cut_index:], axis=1)

def marginal_z(magbin, zbin, nqso, mag_max):
    """Tabulate the marginal distribution of QSOs per sq.deg. per redshift bin with mag < mag_max.
    """
    cut_index = bin_index(magbin, mag_max)
    return zbin, np.sum(nqso[:cut_index], axis=0)

qlf_file=os.getenv("DESIMODEL")+'/data/targets/nzr_qso.dat'
qlftab=Table.read(qlf_file,format='ascii',names=('z','r','dNdzdr'))
zbin=np.unique(qlftab['z'].data)
rbin=np.unique(qlftab['r'].data)
nz,nr=len(zbin),len(rbin)
assert len(qlftab) == nz*nr
nqso_=qlftab['dNdzdr'].data.reshape(nz,nr).transpose()

# %%
#Plot the redshift distribution from the z catalog
z=zcat[1]['Z'][:]
bins = np.arange(min(z),max(z),0.2)
nz_,_,_=plt.hist(z,bins=bins,histtype='step',linewidth=2.);
plt.xlabel(r'$Z$');
plt.ylabel('number');

# %%
zz, nz = marginal_z(rbin, zbin, nqso_, mag_max=23)
plt.plot(zz[zz>1.8],nz[zz>1.8]/nz[zz>1.8].sum(),label='DESI')
plt.hist(z,bins=bins,weights=np.ones(len(z))/nz_.sum(),histtype='step',linewidth=2.,label='mock');
plt.xlabel(r'$Z$');
plt.ylabel(r'$n(Z)$ (normalized)');
plt.legend()

# %% [markdown]
# #### Also we can look at the magnitude of each of the arms [b,r,z].
# #### As the zcatalog does not hace the magnitude information, we can calculate it from the flux as:

# %% [markdown]
# #### $$ m = 22.5 - 2.5 \log_{10}(f) $$

# %%
def magnitud(flux):
    return 22.5-2.5*np.log10(flux)

# %%
plt.figure(figsize=(15,3),dpi=100)

plt.subplot(131)
mag_b = magnitud(zcat[1]['FLUX_G'][:])
bins = np.arange(min(mag_b),max(mag_b),0.5)
plt.hist(mag_b,bins=bins,histtype='step',linewidth=1,label='g');
plt.xlabel('magnitude');
plt.ylabel('#');
plt.legend(loc='upper left')

plt.subplot(132)
mag_r = magnitud(zcat[1]['FLUX_R'][:])
bins = np.arange(min(mag_r),max(mag_r),0.5)
mr,binr,_=plt.hist(mag_r,bins=bins,histtype='step',linewidth=1,label='r');
plt.xlabel('magnitude');
plt.ylabel('#');
plt.legend(loc='upper left')

plt.subplot(133)
mag_z = magnitud(zcat[1]['FLUX_Z'][:])
bins = np.arange(min(mag_z),max(mag_z),0.5)
plt.hist(mag_z,bins=bins,histtype='step',linewidth=1,label='z');
plt.xlabel('magnitude');
plt.ylabel('#');
plt.legend(loc='upper left')


plt.subplots_adjust(wspace=.3)

# %%
#Using the function above lets compare the magnitude r to the expected one. 

r, nr = marginal_mag(rbin, zbin, nqso_, z_min=1.8)
plt.plot(r,nr/nr.sum(),label='DESI')
plt.hist(mag_r,bins=bins,weights=np.ones(len(mag_r))/mr.sum(),histtype='step',linewidth=1,label='mock ');
plt.xlabel('mag-r')
plt.ylabel('n(mag_r) (normalized)')
plt.legend()

# %% [markdown]
# #### We can look at the distriubution of objects in the sky

# %%
plt.scatter(zcat[1]['RA'][:],zcat[1]['DEC'][:],marker='.');
plt.xlabel('RA [deg]');
plt.ylabel('DEC [deg]');

# %% [markdown]
# #### Next we can look at the object distributions for each pixels. For that we define functions to go from angles to pixels and back

# %%
def get_pix(ra,dec,nside=16):
    phi = ra*np.pi / 180.
    th = np.pi/2. - dec*np.pi/180.
    pix = healpy.ang2pix(nside,th,phi,nest=True)
    return pix

def pix2ang_deg(nside,pix,nest=True):
    pix_rad_dec,pix_rad_ra = healpy.pix2ang(nside,pix,nest=nest)
    pix_ra = pix_rad_ra * 180. / np.pi
    pix_dec = (np.pi/2.-pix_rad_dec)*180./np.pi
    return pix_ra, pix_dec

# %%
pix_zcat = get_pix(zcat[1]['RA'][:],zcat[1]['DEC'][:])

# %%
ra_zcat,dec_zcat = pix2ang_deg(16,np.unique(pix_zcat),nest=True)

# %% [markdown]
# #### Here we are just ploting the pixels, in the previous plot we plotted all the objects

# %%
plt.scatter(ra_zcat,dec_zcat,marker='.');
plt.xlabel('RA [deg]');
plt.ylabel('DEC [deg]');

# %% [markdown]
# #### Now lets plot the density of objects per pixels as well at the mean redshift in each pixel

# %%
def get_density(pix,nside):
    bincounts_pix = np.bincount(pix)
    unique_pix = np.unique(pix)
    area_pix = healpy.pixelfunc.nside2pixarea(nside, degrees=True)
    density = bincounts_pix[unique_pix]/area_pix
    return density

# %%
plot1 = plt.scatter(ra_zcat,dec_zcat,c=get_density(pix_zcat,16),marker='.')
cbar1 = plt.colorbar(plot1)
cbar1.set_label(r'$Density \, [\# \, deg^-2]$')
cbar1.update_ticks()
plt.xlabel('RA [deg]')
plt.ylabel('DEC [deg]')

# %%
bincounts_pix = np.bincount(pix_zcat)
bincounts_z = np.bincount(pix_zcat,weights=zcat[1]['Z'][:])

z_pix_zcat = bincounts_z[np.unique(pix_zcat)]/bincounts_pix[np.unique(pix_zcat)]

plot1 = plt.scatter(ra_zcat,dec_zcat,c=z_pix_zcat,marker='.')
cbar1 = plt.colorbar(plot1)
cbar1.set_label(r'$<z>$',size=20)
cbar1.update_ticks()
plt.xlabel('RA [deg]')
plt.ylabel('DEC [deg]')

# %% [markdown]
# # What's netxt?

# %% [markdown]
# #### We can run picca to calculate the flux over-densities as well as the correletions
#
# #### - Here you can find a tutorial to run picca and do a BAO analysis: https://desi.lbl.gov/trac/wiki/LymanAlphaWG/how_to_run_picca
#
# #### We can also run a DLA finder and BAL finder
#
# #### - DLA finder: https://desi.lbl.gov/trac/wiki/LymanAlphaWG/DLAfinder
# #### - BAL finder: https://desi.lbl.gov/trac/wiki/LymanAlphaWG/BALfinder
#
# #### As well feed the mock to redshift fitters:
#
# #### - Redrock
# #### - SQUEZE
# #### - QuasarNet
