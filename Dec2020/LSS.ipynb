# %%
import fitsio
from matplotlib import pyplot as plt
import numpy as np
import sys,os
import importlib

# %% [markdown]
# # LSS Tutorial for December 2020

# %% [markdown]
# ## Everything starts from the target samples. What has been produced by desitarget makes it easy to dig in.
# ### Some simple code taking advantage of this is in https://github.com/desihub/LSS/tree/master/Sandbox/imaging
# ### Some details (needs updating) on the wiki: https://desi.lbl.gov/trac/wiki/ClusteringWG/LSScat

# %%
sys.path.append('/global/homes/a/ajross/LSS/Sandbox/imaging') #change to wherever you have it

# %%
import densvar
import select_samples as ss
# Out:
# 256 True

# %% [markdown]
# ### The target files are split into many healpix files so it is convenient to gather them for a particular target class

# %%
import glob
glob.glob('/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/*.fits')
# Out:
# ['/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-35.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-59.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-88.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-178.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-31.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-37.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-79.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-124.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-17.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-46.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-42.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-188.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-43.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-33.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-104.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-176.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-137.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-101.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-135.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-30.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-58.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-23.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-32.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-75.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-68.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-40.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-38.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-36.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-129.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-103.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-7.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-136.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-51.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-20.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-139.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-44.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-131.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-130.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-105.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-185.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-109.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-93.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-78.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-34.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-189.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-106.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-28.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-85.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-52.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-76.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-49.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-100.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-180.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-25.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-141.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-66.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-91.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-159.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-151.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-47.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-97.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-18.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-179.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-127.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-39.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-70.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-132.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-69.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-2.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-62.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-87.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-181.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-53.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-26.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-24.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-3.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-98.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-77.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-72.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-154.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-133.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-102.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-182.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-174.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-183.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-80.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-143.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-175.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-123.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-74.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-19.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-140.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-99.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-89.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-82.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-63.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-16.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-41.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-27.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-138.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-71.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-48.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-184.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-22.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-110.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-0.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-90.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-157.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-10.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-152.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-96.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-67.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-8.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-65.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-134.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-177.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-142.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-9.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-122.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-126.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-21.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-121.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-73.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-120.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-107.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-29.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-125.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-117.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-45.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-108.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-111.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-191.fits',
#  '/project/projectdirs/desi/target/catalogs/dr9m/0.44.0/targets/main/resolve/dark/targets-dark-hp-64.fits']

# %% [raw]
# '''
# already done, so not doing again
# ss.gather_targets('LRG') #Note, output is hard-coded to ajross/dr9
# '''

# %%
#look at LRG target density variations over full footprint
#this uses random file produced with targeting /global/cfs/cdirs/desi/target/catalogs/dr9m/0.44.0/randoms/resolve/randoms*
#There are 10 of them, each conveniently with a density of 5000/deg2
#Make sure any mask bit and nobs cuts are consistent! (Some are applied at targeting to data samples, none to randoms)
densvar.plot_hpdens('LRG') #
# Out:
# 11174376
# 11174376
# 10569539
# 10569539
# 102802203
# 97943958
# 92755252
# 92755252
# randoms done

# %%
#look specifically at three regions: BASS/MzLS, DECaLS NGC, DECaLS SGC
densvar.plot_hpdens('LRG','N')
densvar.plot_hpdens('LRG','DN')
densvar.plot_hpdens('LRG','DS')
# Out:
# 11174376
# 11174376
# 10569539
# 10569539
# 102802203
# 97943958
# 92755252
# 92755252
# randoms done
# 11174376
# 11174376
# 10569539
# 10569539
# 102802203
# 97943958
# 92755252
# 92755252
# randoms done
# 11174376
# 11174376
# 10569539
# 10569539
# 102802203
# 97943958
# 92755252
# 92755252
# randoms done

# %% [markdown]
# ### See more at https://github.com/desihub/LSS/blob/master/Sandbox/imaging/examples.ipynb

# %% [markdown]
# ## End-to-end simulations: Some early examples of what to expect from LSS catalogs

# %%
glob.glob('/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/*')
# Out:
# ['/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/QSO_oneperztrue_clus.dat.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/targets_oneper_jmtl_jztrue.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/e2etiles_run9.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/QSO_oneper_clus.dat.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/e2etiles_run16.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/nbar_oneper_LRG.dat',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/nbar_oneper_QSO.dat',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/e2etiles_run12.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/randoms_mtl_cuttod.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/e2etiles_run1.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/QSO_oneper_clus.ran.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/e2etiles_run7.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/e2etiles_run4.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/QSO_oneper_full.ran.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/LRG_oneperztrue_clus.dat.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/e2etiles_run8.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/e2etiles_run10.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/e2etiles_run0.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/nbar_oneperztrue_QSO.dat',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/LRG_oneperztrue_full.ran.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/QSO_oneperztrue_full.dat.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/LRG_oneper_full.ran.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/LRG_oneper_clus.dat.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/QSO_oneper_full.dat.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/QSO_oneperztrue_full.ran.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/e2etiles_run5.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/e2etiles_run15.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/nbar_oneperztrue_LRG.dat',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/LRG_oneper_clus.ran.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/e2etiles_run13.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/LRG_oneperztrue_full.dat.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/e2etiles_run3.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/QSO_oneperztrue_clus.ran.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/randoms',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/LRG_oneper_full.dat.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/e2etiles_run2.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/LRG_oneperztrue_clus.ran.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/e2etiles_run6.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/e2etiles_run14.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/targets_oneper_jmtl.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/randoms_oneper_jmtl.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/targets_oneper.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/e2etiles_run11.fits',
#  '/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/targets_oneper_jmtl_jzcat.fits']

# %% [markdown]
# ### The files with 'clus' in the names are meant to be used for clustering measurements

# %%
fd = fitsio.read('/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/LRG_oneper_clus.dat.fits')

# %%
fd.dtype.names
# Out:
# ('TARGETID', 'RA', 'DEC', 'Z', 'WEIGHT', 'NZ', 'WEIGHT_FKP')

# %% [markdown]
# ### Those should be the minimal set of columns needed for 2pt statistics

# %%
fr = fitsio.read('/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/LRG_oneper_clus.ran.fits')

# %%
fr.dtype.names
# Out:
# ('TARGETID', 'RA', 'DEC', 'WEIGHT', 'Z', 'NZ', 'WEIGHT_FKP')

# %% [markdown]
# ### Randoms files have the same columns

# %% [markdown]
# ### Those files only include the galaxies that got good redshifts in the desired range
# ### 'full' files contain all targets that were identified as reachable by a positioner that later got a good spectrum
# ### they also contain all of the relative photometric and spectroscopic information that could possibly have been used to identify them as targets, good redshifts, and then have cuts applied to get to the clustering catalogs

# %%
fdf = fitsio.read('/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/LRG_oneper_full.dat.fits')

# %%
fdf.dtype.names
# Out:
# ('LOCATION',
#  'FIBER',
#  'TARGETID',
#  'TILE',
#  'TILELOCID',
#  'PROGRAM',
#  'NTILE',
#  'RELEASE',
#  'BRICKID',
#  'BRICKNAME_mtl',
#  'BRICK_OBJID',
#  'MORPHTYPE',
#  'RA',
#  'DEC',
#  'RA_IVAR',
#  'DEC_IVAR',
#  'DCHISQ',
#  'FLUX_G',
#  'FLUX_R',
#  'FLUX_Z',
#  'FLUX_W1',
#  'FLUX_W2',
#  'FLUX_W3',
#  'FLUX_W4',
#  'FLUX_IVAR_G',
#  'FLUX_IVAR_R',
#  'FLUX_IVAR_Z',
#  'FLUX_IVAR_W1',
#  'FLUX_IVAR_W2',
#  'FLUX_IVAR_W3',
#  'FLUX_IVAR_W4',
#  'MW_TRANSMISSION_G',
#  'MW_TRANSMISSION_R',
#  'MW_TRANSMISSION_Z',
#  'MW_TRANSMISSION_W1',
#  'MW_TRANSMISSION_W2',
#  'MW_TRANSMISSION_W3',
#  'MW_TRANSMISSION_W4',
#  'NOBS_G',
#  'NOBS_R',
#  'NOBS_Z',
#  'FRACFLUX_G',
#  'FRACFLUX_R',
#  'FRACFLUX_Z',
#  'FRACMASKED_G',
#  'FRACMASKED_R',
#  'FRACMASKED_Z',
#  'FRACIN_G',
#  'FRACIN_R',
#  'FRACIN_Z',
#  'ALLMASK_G',
#  'ALLMASK_R',
#  'ALLMASK_Z',
#  'WISEMASK_W1',
#  'WISEMASK_W2',
#  'PSFDEPTH_G',
#  'PSFDEPTH_R',
#  'PSFDEPTH_Z',
#  'GALDEPTH_G',
#  'GALDEPTH_R',
#  'GALDEPTH_Z',
#  'FRACDEV',
#  'FRACDEV_IVAR',
#  'SHAPEDEV_R',
#  'SHAPEDEV_R_IVAR',
#  'SHAPEDEV_E1',
#  'SHAPEDEV_E1_IVAR',
#  'SHAPEDEV_E2',
#  'SHAPEDEV_E2_IVAR',
#  'SHAPEEXP_R',
#  'SHAPEEXP_R_IVAR',
#  'SHAPEEXP_E1',
#  'SHAPEEXP_E1_IVAR',
#  'SHAPEEXP_E2',
#  'SHAPEEXP_E2_IVAR',
#  'FIBERFLUX_G',
#  'FIBERFLUX_R',
#  'FIBERFLUX_Z',
#  'FIBERTOTFLUX_G',
#  'FIBERTOTFLUX_R',
#  'FIBERTOTFLUX_Z',
#  'REF_CAT',
#  'REF_ID',
#  'GAIA_PHOT_G_MEAN_MAG',
#  'GAIA_PHOT_G_MEAN_FLUX_OVER_ERROR',
#  'GAIA_PHOT_BP_MEAN_MAG',
#  'GAIA_PHOT_BP_MEAN_FLUX_OVER_ERROR',
#  'GAIA_PHOT_RP_MEAN_MAG',
#  'GAIA_PHOT_RP_MEAN_FLUX_OVER_ERROR',
#  'GAIA_PHOT_BP_RP_EXCESS_FACTOR',
#  'GAIA_ASTROMETRIC_SIGMA5D_MAX',
#  'GAIA_ASTROMETRIC_PARAMS_SOLVED',
#  'GAIA_ASTROMETRIC_EXCESS_NOISE',
#  'GAIA_DUPLICATED_SOURCE',
#  'PARALLAX',
#  'PARALLAX_IVAR',
#  'PMRA',
#  'PMRA_IVAR',
#  'PMDEC',
#  'PMDEC_IVAR',
#  'MASKBITS',
#  'EBV',
#  'PHOTSYS',
#  'DESI_TARGET',
#  'BGS_TARGET',
#  'MWS_TARGET',
#  'SUBPRIORITY',
#  'OBSCONDITIONS',
#  'PRIORITY_INIT',
#  'NUMOBS_INIT',
#  'HPXPIXEL',
#  'NUMOBS_MORE_mtl',
#  'PRIORITY',
#  'BRICKNAME_zcat',
#  'SPECTYPE',
#  'Z',
#  'ZERR',
#  'ZWARN',
#  'NUMOBS',
#  'NUMOBS_MORE_zcat',
#  'FRACZ_TILELOCID')

# %% [markdown]
# ### The TILELOCID information is unique the LSS catalogs. This combines the tile number and the fiber location. The same tilelocid can show up for multiple targets. Only one will get assigned. Each target can show up at multiple tilelocid; each is given either the first it shows up in or the one it was assigned in.
# ### FRACZ_TILELOCID then gives basically 1/N_TILELOCID

# %%
plt.hist(fdf['FRACZ_TILELOCID'])
plt.show()

# %% [markdown]
# ### TILE info is stored as a string of all of the tiles a target hits, separated by '-'

# %%
nt = np.char.count(fdf['TILE'],'-')+1
print(np.unique(nt))
# Out:
# [1 2 3 4 5 6 7 8 9]

# %%
plt.hist(fdf['NTILE'],bins=8)
plt.show()

# %%
fdf['TILE'][:10]
# Out:
# array(['13342', '13342', '13342', '13342', '13342', '13342', '13342',
#        '13342', '13342', '13342'], dtype='<U100')

# %%
frf = fitsio.read('/global/cfs/cdirs/desi/datachallenge/onepercent/catalogs/dark/LRG_oneper_full.ran.fits')

# %%
#the full randoms also have all of that info and then info they inheret from the imaging randoms
frf.dtype.names
# Out:
# ('LOCATION',
#  'FIBER',
#  'TARGETID',
#  'TILE',
#  'TILELOCID',
#  'PROGRAM',
#  'NTILE',
#  'RA',
#  'DEC',
#  'BRICKNAME',
#  'NOBS_G',
#  'NOBS_R',
#  'NOBS_Z',
#  'PSFDEPTH_G',
#  'PSFDEPTH_R',
#  'PSFDEPTH_Z',
#  'GALDEPTH_G',
#  'GALDEPTH_R',
#  'GALDEPTH_Z',
#  'PSFDEPTH_W1',
#  'PSFDEPTH_W2',
#  'PSFSIZE_G',
#  'PSFSIZE_R',
#  'PSFSIZE_Z',
#  'APFLUX_G',
#  'APFLUX_R',
#  'APFLUX_Z',
#  'APFLUX_IVAR_G',
#  'APFLUX_IVAR_R',
#  'APFLUX_IVAR_Z',
#  'MASKBITS',
#  'WISEMASK_W1',
#  'WISEMASK_W2',
#  'EBV',
#  'PHOTSYS',
#  'HPXPIXEL',
#  'DESI_TARGET',
#  'SV1_DESI_TARGET',
#  'NUMOBS_INIT',
#  'NUMOBS_MORE',
#  'PRIORITY',
#  'OBSCONDITIONS',
#  'SUBPRIORITY')

# %%
plt.scatter(frf['RA'],frf['DEC'],c=frf['NTILE'],s=.1)
plt.show()

# %%
#zoom in on one of the regions
plt.scatter(frf['RA'],frf['DEC'],c=frf['NTILE'],s=.1)
plt.xlim(-5,20)
plt.ylim(-1,10)
plt.colorbar()
plt.show()

# %% [markdown]
# ### jump to https://github.com/desihub/LSS/blob/master/Sandbox/xitools_e2e.py to get xi

# %% [markdown]
# ## Smaller catalogs exist with !real! data
# ### /project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats
# ### Tiles are all isolated, so this is per tile and night observed

# %%
glob.glob('/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/*')
# Out:
# ['/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG70005_20200228_full.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/QSO68000_20200314_full.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG70005_20200228_full.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG70002_20200304_full.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG70006_20200304_clustering.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG70006_20200304_clustering.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG70005_20200219_full.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG70005_20200220_full.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG68001_20200315_full.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG70003_20200224_full.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/QSO68002_20200315_full.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG70003_20200219_clustering.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG70003_20200304_full.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG70002_20200304_full.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG70005_20200220_full.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG70003_20200228_clustering.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/QSO68002_20200315_clustering.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG68002_20200315_clustering.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/QSO68001_20200315_full.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG70006_20200303_clustering.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG70006_20200304_full.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG70003_20200219_clustering.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG70005_20200228_clustering.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG70003_20200226_full.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG70005_20200303_full.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG70006_20200303_full.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG67142_20200315_full.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/QSO68002_20200315_clustering.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG70005_20200219_full.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG70003_20200304_full.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG68001_20200315_clustering.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG68002_20200315_clustering.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG70002_20200304_clustering.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG70003_20200219_full.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG68002_20200315_full.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG67230_20200315_full.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG70006_20200304_full.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG68001_20200315_clustering.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG67230_20200315_clustering.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG70005_20200228_clustering.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG67142_20200315_clustering.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG70003_20200228_clustering.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG70006_20200303_clustering.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG70003_20200228_full.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG70005_20200303_full.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG70002_20200303_full.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG68000_20200314_full.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/test',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG70003_20200226_full.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG67230_20200315_full.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG68001_20200315_full.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG68000_20200314_full.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG70006_20200303_full.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG70004_20200219_clustering.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/QSO68002_20200315_full.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/QSO68000_20200314_full.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG70004_20200219_clustering.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG67142_20200315_full.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG70002_20200303_full.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/QSO68001_20200315_full.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG70003_20200228_full.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG68002_20200315_full.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG70004_20200219_full.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG70004_20200219_full.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG67230_20200315_clustering.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG70003_20200224_full.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/QSO68001_20200315_clustering.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/QSO68001_20200315_clustering.ran.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG67142_20200315_clustering.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG70002_20200304_clustering.dat.fits',
#  '/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/LRG70003_20200219_full.ran.fits']

# %%
fr = fitsio.read('/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG67142_20200315_clustering.ran.fits')

# %%
fr.dtype.names
# Out:
# ('RA', 'DEC', 'Z', 'WEIGHT')

# %%
fd = fitsio.read('/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG67142_20200315_clustering.dat.fits')

# %%
fd.dtype.names
# Out:
# ('RA', 'DEC', 'Z', 'WEIGHT')

# %%
frf = fitsio.read('/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG67142_20200315_full.ran.fits')

# %%
frf.dtype.names
# Out:
# ('TARGETID',
#  'LOCATION',
#  'FIBER',
#  'TARGET_RA',
#  'TARGET_DEC',
#  'FA_TARGET',
#  'FA_TYPE',
#  'RA',
#  'DEC',
#  'BRICKNAME',
#  'NOBS_G',
#  'NOBS_R',
#  'NOBS_Z',
#  'PSFDEPTH_G',
#  'PSFDEPTH_R',
#  'PSFDEPTH_Z',
#  'GALDEPTH_G',
#  'GALDEPTH_R',
#  'GALDEPTH_Z',
#  'PSFDEPTH_W1',
#  'PSFDEPTH_W2',
#  'PSFSIZE_G',
#  'PSFSIZE_R',
#  'PSFSIZE_Z',
#  'APFLUX_G',
#  'APFLUX_R',
#  'APFLUX_Z',
#  'APFLUX_IVAR_G',
#  'APFLUX_IVAR_R',
#  'APFLUX_IVAR_Z',
#  'MASKBITS',
#  'WISEMASK_W1',
#  'WISEMASK_W2',
#  'EBV',
#  'PHOTSYS',
#  'HPXPIXEL',
#  'DESI_TARGET',
#  'SV1_DESI_TARGET',
#  'Z',
#  'PRIORITY')

# %%
fdf = fitsio.read('/project/projectdirs/desi/users/ajross/catalogs/minisv2/LSScats/ELG67142_20200315_full.dat.fits')

# %%
fdf.dtype.names
# Out:
# ('TARGETID',
#  'FIBER',
#  'LOCATION',
#  'NUMOBS_MORE',
#  'RELEASE',
#  'BRICKID',
#  'BRICKNAME',
#  'BRICK_OBJID',
#  'MORPHTYPE',
#  'RA',
#  'RA_IVAR',
#  'DEC',
#  'DEC_IVAR',
#  'EBV',
#  'FLUX_G',
#  'FLUX_R',
#  'FLUX_Z',
#  'FLUX_IVAR_G',
#  'FLUX_IVAR_R',
#  'FLUX_IVAR_Z',
#  'MW_TRANSMISSION_G',
#  'MW_TRANSMISSION_R',
#  'MW_TRANSMISSION_Z',
#  'FRACFLUX_G',
#  'FRACFLUX_R',
#  'FRACFLUX_Z',
#  'FRACMASKED_G',
#  'FRACMASKED_R',
#  'FRACMASKED_Z',
#  'FRACIN_G',
#  'FRACIN_R',
#  'FRACIN_Z',
#  'NOBS_G',
#  'NOBS_R',
#  'NOBS_Z',
#  'PSFDEPTH_G',
#  'PSFDEPTH_R',
#  'PSFDEPTH_Z',
#  'GALDEPTH_G',
#  'GALDEPTH_R',
#  'GALDEPTH_Z',
#  'FLUX_W1',
#  'FLUX_W2',
#  'FLUX_W3',
#  'FLUX_W4',
#  'FLUX_IVAR_W1',
#  'FLUX_IVAR_W2',
#  'FLUX_IVAR_W3',
#  'FLUX_IVAR_W4',
#  'MW_TRANSMISSION_W1',
#  'MW_TRANSMISSION_W2',
#  'MW_TRANSMISSION_W3',
#  'MW_TRANSMISSION_W4',
#  'ALLMASK_G',
#  'ALLMASK_R',
#  'ALLMASK_Z',
#  'FIBERFLUX_G',
#  'FIBERFLUX_R',
#  'FIBERFLUX_Z',
#  'FIBERTOTFLUX_G',
#  'FIBERTOTFLUX_R',
#  'FIBERTOTFLUX_Z',
#  'REF_EPOCH',
#  'WISEMASK_W1',
#  'WISEMASK_W2',
#  'MASKBITS',
#  'FRACDEV',
#  'FRACDEV_IVAR',
#  'SHAPEDEV_R',
#  'SHAPEDEV_E1',
#  'SHAPEDEV_E2',
#  'SHAPEDEV_R_IVAR',
#  'SHAPEDEV_E1_IVAR',
#  'SHAPEDEV_E2_IVAR',
#  'SHAPEEXP_R',
#  'SHAPEEXP_E1',
#  'SHAPEEXP_E2',
#  'SHAPEEXP_R_IVAR',
#  'SHAPEEXP_E1_IVAR',
#  'SHAPEEXP_E2_IVAR',
#  'REF_ID',
#  'REF_CAT',
#  'GAIA_PHOT_G_MEAN_MAG',
#  'GAIA_PHOT_G_MEAN_FLUX_OVER_ERROR',
#  'GAIA_PHOT_BP_MEAN_MAG',
#  'GAIA_PHOT_BP_MEAN_FLUX_OVER_ERROR',
#  'GAIA_PHOT_RP_MEAN_MAG',
#  'GAIA_PHOT_RP_MEAN_FLUX_OVER_ERROR',
#  'GAIA_PHOT_BP_RP_EXCESS_FACTOR',
#  'GAIA_ASTROMETRIC_EXCESS_NOISE',
#  'GAIA_DUPLICATED_SOURCE',
#  'GAIA_ASTROMETRIC_SIGMA5D_MAX',
#  'GAIA_ASTROMETRIC_PARAMS_SOLVED',
#  'PARALLAX',
#  'PARALLAX_IVAR',
#  'PMRA',
#  'PMRA_IVAR',
#  'PMDEC',
#  'PMDEC_IVAR',
#  'PHOTSYS',
#  'CMX_TARGET',
#  'SUBPRIORITY',
#  'OBSCONDITIONS',
#  'PRIORITY_INIT',
#  'NUMOBS_INIT',
#  'HPXPIXEL',
#  'PRIORITY',
#  'LOCATION_ASSIGNED',
#  'CHI2',
#  'COEFF',
#  'Z',
#  'ZERR',
#  'ZWARN',
#  'NPIXELS',
#  'SPECTYPE',
#  'SUBTYPE',
#  'NCOEFF',
#  'DELTACHI2',
#  'NUMEXP',
#  'NUMTILE',
#  'LOC')

# %% [markdown]
# ### You can see above, similar (but more restricted) data model

# %%
plt.plot(fr['RA'],fr['DEC'],'k,',label='randoms')
plt.plot(fdf['RA'],fdf['DEC'],'g.',label='ELG targets')
plt.plot(fd['RA'],fd['DEC'],'b.',label='observed ELGs')
plt.legend()
plt.show()

# %% [markdown]
# ### jump to https://github.com/desihub/LSS/blob/master/Sandbox/xitools_minisv.py to get xi
